# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# %%
dates = ["01-01-2024", "01-08-2024", "03-09-2024", "09-10-2024"]

# %%
df = pd.DataFrame(dates, columns=["Dates"], dtype='datetime64[ns]')
df
# Out:
#        Dates
# 0 2024-01-01
# 1 2024-01-08
# 2 2024-03-09
# 3 2024-09-10

# %%
df.dtypes
# Out:
# Dates    datetime64[ns]
# dtype: object

# %%
df["DayOfWeek"] = df["Dates"].dt.day_name()

# %%
df
# Out:
#        Dates DayOfWeek
# 0 2024-01-01    Monday
# 1 2024-01-08    Monday
# 2 2024-03-09  Saturday
# 3 2024-09-10   Tuesday

# %%
# Define the order of days (Monday to Sunday) using CategoricalDtype
day_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
df["DayOfWeek"] = pd.Categorical(df["DayOfWeek"], categories=day_order, ordered=True)

# %%
# Count the occurrences of each day of the week
day_counts = df["DayOfWeek"].value_counts().sort_index()

# %%
# Plotting the bar chart with ordered days
day_counts.plot(kind='bar', color='skyblue')
plt.title("Number of Instances per day of the Week")
plt.xlabel("Day of the Week")
plt.ylabel("Number of Instances")
plt.xticks(rotation=45)  # Rotate x labels for better readability

# Set y-axis to use integer-only ticks
plt.gca().yaxis.set_major_locator(MaxNLocator(integer=True))

plt.show()
